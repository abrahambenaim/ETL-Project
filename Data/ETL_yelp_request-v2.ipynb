# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Yelp API Key
gkey = 'fxuoEjmZHd5kA1x20u4z2waSsXfTm49pWr2F6ac-htERJ0haCqXH949tlmDYt9lhy4MC6nBJjt2llMwhQJfxbwX69QlFkI221WkMDZTn7NMQBaXRrWGBFzCrg4-9XXYx'

# %%
from etl_clean_ip import zip_list
# Out:
# /Users/monicamalarcon/Dropbox/School/UM_Bootcamp/Work_Bootcamp/13 - ETL-Project/ETL-project/ETL-Project/Data/etl_clean_ip.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   top30_disparity['zip_code'] = top30_disparity['zip_code'].astype(int)
# /Users/monicamalarcon/Dropbox/School/UM_Bootcamp/Work_Bootcamp/13 - ETL-Project/ETL-project/ETL-Project/Data/etl_clean_ip.py:232: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   top30_disparity['Avg_income'] = top30_disparity['Avg_income'].round(3)

# %%
#set up base url
# base url
base_url = "https://api.yelp.com/v3/businesses/search"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(target_loc,target_key,target_type):
    params = {
    "location": target_loc,
    "term": target_key,
    "categories": target_type,
}
    return params

# run a request using our params dictionary
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
# Import zip list
zip_list 


#cities_pd.shape[0] #use .shape[0] to count the number of rows
# Out:
# [33142,
#  33127,
#  33147,
#  33125,
#  33136,
#  33012,
#  33167,
#  33126,
#  33150,
#  33032,
#  33130,
#  33162,
#  33034,
#  33055,
#  33056,
#  33174,
#  33172,
#  33033,
#  33168,
#  33190,
#  33169,
#  33181,
#  33030,
#  33014,
#  33193,
#  33016,
#  33161,
#  33184,
#  33194,
#  33035]

# %%
# create empty lists to hold yelp data
names = []
streets = []
zipcodes= []
cities = []
states = []
ratings = []
price = []

#define Yelp function to get restaurant data
def get_restaurants(loc):
    
    #these are the additional params
    add_params = { "limit" : 20, "sort_by": "distance"}

    #these are the original params
    params = s_params(loc,"restaurants","restaurants, All")

    #add additional params to our params from before
    s1_params = {**params,**add_params}

    s1_results = s_query(base_url,headers,s1_params)
    
    try:
        name = s1_results["businesses"][0]["name"]
        address1 = s1_results["businesses"][0]["location"]["address1"]
        city = s1_results["businesses"][0]["location"]["city"]
        state = s1_results["businesses"][0]["location"]["state"]
        zipcode = s1_results["businesses"][0]["location"]["zip_code"]
        rating = s1_results["businesses"][0]["rating"]
        price = s1_results["businesses"][0]["price"]
        output = [name,address1,city,state,zipcode,rating,price] 
        print(output)
    except KeyError:
        print(f'Key not found. Missing data.')
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
      
    return output

# %%
restaurants = []
zipnum = 0

print("Beginning Data Retrieval")
print("------------------------")
for zipc in zip_list:
    loc = zipc
    print(f'Searching {loc}.')

    output = get_restaurants(loc)
    restaurants.append(output)
#    print(f'Found {number} restaurants.')
    for res in restaurants:
        try:
            names.append(restaurants[0][0])
            streets.append(restaurants[0][1])
            cities.append(restaurants[0][2])
            states.append(restaurants[0][3])
            zipcodes.append(restaurants[0][4])
            ratings.append(restaurants[0][5])
            price.append(restaurants[0][6])
            number = number + 1
            print(f'Data collected for restaurant {number} in {loc}.')
                    
        except(KeyError, IndexError):
            output = ["NaN","NaN","NaN","NaN","NaN","NaN","NaN"]
            names.append(restaurants[0][0])
            streets.append(restaurants[0][1])
            cities.append(restaurants[0][2])
            states.append(restaurants[0][3])
            zipcodes.append(restaurants[0][4])
            ratings.append(restaurants[0][5])
            price.append(restaurants[0][6])
            number = number + 1
            print(f'Data missing for restaurant {number} in {loc}.')
          
#    print(f'{len(names)} total restaurants in {loc}.')
    zipnum = zipnum + 1
    print(f'zipcode {zipnum} is {loc}')
print("-----------------------------------")
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# ------------------------
# Searching 33142.
# ['KFC', '3855 NW 27th Ave', 'Miami', 'FL', '33142', 2.5, '$']
# Data collected for restaurant 2 in 33142.
# 2326 total restaurants in 33142.
# zipcode 1 is 33142
# Searching 33127.
# ['DoggyStyle Miami Hot Dogs', '', 'Miami', 'FL', '33127', 4.5, '$$']
# Data collected for restaurant 3 in 33127.
# Data collected for restaurant 4 in 33127.
# 2328 total restaurants in 33127.
# zipcode 2 is 33127
# Searching 33147.
# ['Benettes Pizza and Subs', '8852 NW 22nd Ave', 'Miami', 'FL', '33147', 3.0, '$']
# Data collected for restaurant 5 in 33147.
# Data collected for restaurant 6 in 33147.
# Data collected for restaurant 7 in 33147.
# 2331 total restaurants in 33147.
# zipcode 3 is 33147
# Searching 33125.
# ['Fritanga Cana Brava', '2795 NW 7th St', 'Miami', 'FL', '33125', 4.5, '$']
# Data collected for restaurant 8 in 33125.
# Data collected for restaurant 9 in 33125.
# Data collected for restaurant 10 in 33125.
# Data collected for restaurant 11 in 33125.
# 2335 total restaurants in 33125.
# zipcode 4 is 33125
# Searching 33136.
# Key not found. Missing data.
# Data collected for restaurant 12 in 33136.
# Data collected for restaurant 13 in 33136.
# Data collected for restaurant 14 in 33136.
# Data collected for restaurant 15 in 33136.
# Data collected for restaurant 16 in 33136.
# 2340 total restaurants in 33136.
# zipcode 5 is 33136
# Searching 33012.
# ['Burger King', '891 West 49th Street', 'Hialeah', 'FL', '33012', 2.5, '$']
# Data collected for restaurant 17 in 33012.
# Data collected for restaurant 18 in 33012.
# Data collected for restaurant 19 in 33012.
# Data collected for restaurant 20 in 33012.
# Data collected for restaurant 21 in 33012.
# Data collected for restaurant 22 in 33012.
# 2346 total restaurants in 33012.
# zipcode 6 is 33012
# Searching 33167.
# Key not found. Missing data.
# Data collected for restaurant 23 in 33167.
# Data collected for restaurant 24 in 33167.
# Data collected for restaurant 25 in 33167.
# Data collected for restaurant 26 in 33167.
# Data collected for restaurant 27 in 33167.
# Data collected for restaurant 28 in 33167.
# Data collected for restaurant 29 in 33167.
# 2353 total restaurants in 33167.
# zipcode 7 is 33167
# Searching 33126.
# Key not found. Missing data.
# Data collected for restaurant 30 in 33126.
# Data collected for restaurant 31 in 33126.
# Data collected for restaurant 32 in 33126.
# Data collected for restaurant 33 in 33126.
# Data collected for restaurant 34 in 33126.
# Data collected for restaurant 35 in 33126.
# Data collected for restaurant 36 in 33126.
# Data collected for restaurant 37 in 33126.
# 2361 total restaurants in 33126.
# zipcode 8 is 33126
# Searching 33150.
# ['Checkers', '8080 NW 7th Ave', 'Miami', 'FL', '33150', 2.0, '$']
# Data collected for restaurant 38 in 33150.
# Data collected for restaurant 39 in 33150.
# Data collected for restaurant 40 in 33150.
# Data collected for restaurant 41 in 33150.
# Data collected for restaurant 42 in 33150.
# Data collected for restaurant 43 in 33150.
# Data collected for restaurant 44 in 33150.
# Data collected for restaurant 45 in 33150.
# Data collected for restaurant 46 in 33150.
# 2370 total restaurants in 33150.
# zipcode 9 is 33150
# Searching 33032.
# Key not found. Missing data.
# Data collected for restaurant 47 in 33032.
# Data collected for restaurant 48 in 33032.
# Data collected for restaurant 49 in 33032.
# Data collected for restaurant 50 in 33032.
# Data collected for restaurant 51 in 33032.
# Data collected for restaurant 52 in 33032.
# Data collected for restaurant 53 in 33032.
# Data collected for restaurant 54 in 33032.
# Data collected for restaurant 55 in 33032.
# Data collected for restaurant 56 in 33032.
# 2380 total restaurants in 33032.
# zipcode 10 is 33032
# Searching 33130.
# ['China Lee Restaurant', '559 SW 8th St', 'Miami', 'FL', '33130', 3.0, '$']
# Data collected for restaurant 57 in 33130.
# Data collected for restaurant 58 in 33130.
# Data collected for restaurant 59 in 33130.
# Data collected for restaurant 60 in 33130.
# Data collected for restaurant 61 in 33130.
# Data collected for restaurant 62 in 33130.
# Data collected for restaurant 63 in 33130.
# Data collected for restaurant 64 in 33130.
# Data collected for restaurant 65 in 33130.
# Data collected for restaurant 66 in 33130.
# Data collected for restaurant 67 in 33130.
# 2391 total restaurants in 33130.
# zipcode 11 is 33130
# Searching 33162.
# ['Popeyes Louisiana Kitchen', '1000 NE 163rd St', 'Miami', 'FL', '33162', 2.5, '$']
# Data collected for restaurant 68 in 33162.
# Data collected for restaurant 69 in 33162.
# Data collected for restaurant 70 in 33162.
# Data collected for restaurant 71 in 33162.
# Data collected for restaurant 72 in 33162.
# Data collected for restaurant 73 in 33162.
# Data collected for restaurant 74 in 33162.
# Data collected for restaurant 75 in 33162.
# Data collected for restaurant 76 in 33162.
# Data collected for restaurant 77 in 33162.
# Data collected for restaurant 78 in 33162.
# Data collected for restaurant 79 in 33162.
# 2403 total restaurants in 33162.
# zipcode 12 is 33162
# Searching 33034.
# ['Los Potosinos Taqueria', '19203 SW 376th St', 'Homestead', 'FL', '33034', 4.5, '$']
# Data collected for restaurant 80 in 33034.
# Data collected for restaurant 81 in 33034.
# Data collected for restaurant 82 in 33034.
# Data collected for restaurant 83 in 33034.
# Data collected for restaurant 84 in 33034.
# Data collected for restaurant 85 in 33034.
# Data collected for restaurant 86 in 33034.
# Data collected for restaurant 87 in 33034.
# Data collected for restaurant 88 in 33034.
# Data collected for restaurant 89 in 33034.
# Data collected for restaurant 90 in 33034.
# Data collected for restaurant 91 in 33034.
# Data collected for restaurant 92 in 33034.
# 2416 total restaurants in 33034.
# zipcode 13 is 33034
# Searching 33055.
# ['Papa  Pizza Cubana ', '4625 NW 199th St', 'Miami Gardens', 'FL', '33055', 4.5, '$']
# Data collected for restaurant 93 in 33055.
# Data collected for restaurant 94 in 33055.
# Data collected for restaurant 95 in 33055.
# Data collected for restaurant 96 in 33055.
# Data collected for restaurant 97 in 33055.
# Data collected for restaurant 98 in 33055.
# Data collected for restaurant 99 in 33055.
# Data collected for restaurant 100 in 33055.
# Data collected for restaurant 101 in 33055.
# Data collected for restaurant 102 in 33055.
# Data collected for restaurant 103 in 33055.
# Data collected for restaurant 104 in 33055.
# Data collected for restaurant 105 in 33055.
# Data collected for restaurant 106 in 33055.
# 2430 total restaurants in 33055.
# zipcode 14 is 33055
# Searching 33056.
# ['World Famous', '19401 NW 27th Ave', 'Miami Gardens', 'FL', '33056', 4.0, '$$']
# Data collected for restaurant 107 in 33056.
# Data collected for restaurant 108 in 33056.
# Data collected for restaurant 109 in 33056.
# Data collected for restaurant 110 in 33056.
# Data collected for restaurant 111 in 33056.
# Data collected for restaurant 112 in 33056.
# Data collected for restaurant 113 in 33056.
# Data collected for restaurant 114 in 33056.
# Data collected for restaurant 115 in 33056.
# Data collected for restaurant 116 in 33056.
# Data collected for restaurant 117 in 33056.
# Data collected for restaurant 118 in 33056.
# Data collected for restaurant 119 in 33056.
# Data collected for restaurant 120 in 33056.
# Data collected for restaurant 121 in 33056.
# 2445 total restaurants in 33056.
# zipcode 15 is 33056
# Searching 33174.
# ["McDonald's", '9850 SW 8th St', 'Miami', 'FL', '33174', 2.0, '$']
# Data collected for restaurant 122 in 33174.
# Data collected for restaurant 123 in 33174.
# Data collected for restaurant 124 in 33174.
# Data collected for restaurant 125 in 33174.
# Data collected for restaurant 126 in 33174.
# Data collected for restaurant 127 in 33174.
# Data collected for restaurant 128 in 33174.
# Data collected for restaurant 129 in 33174.
# Data collected for restaurant 130 in 33174.
# Data collected for restaurant 131 in 33174.
# Data collected for restaurant 132 in 33174.
# Data collected for restaurant 133 in 33174.
# Data collected for restaurant 134 in 33174.
# Data collected for restaurant 135 in 33174.
# Data collected for restaurant 136 in 33174.
# Data collected for restaurant 137 in 33174.
# 2461 total restaurants in 33174.
# zipcode 16 is 33174
# Searching 33172.
# Key not found. Missing data.
# Data collected for restaurant 138 in 33172.
# Data collected for restaurant 139 in 33172.
# Data collected for restaurant 140 in 33172.
# Data collected for restaurant 141 in 33172.
# Data collected for restaurant 142 in 33172.
# Data collected for restaurant 143 in 33172.
# Data collected for restaurant 144 in 33172.
# Data collected for restaurant 145 in 33172.
# Data collected for restaurant 146 in 33172.
# Data collected for restaurant 147 in 33172.
# Data collected for restaurant 148 in 33172.
# Data collected for restaurant 149 in 33172.
# Data collected for restaurant 150 in 33172.
# Data collected for restaurant 151 in 33172.
# Data collected for restaurant 152 in 33172.
# Data collected for restaurant 153 in 33172.
# Data collected for restaurant 154 in 33172.
# 2478 total restaurants in 33172.
# zipcode 17 is 33172
# Searching 33033.
# ['Subway Restaurants', '13600 SW 288th Street', 'Homestead', 'FL', '33033', 2.5, '$']
# Data collected for restaurant 155 in 33033.
# Data collected for restaurant 156 in 33033.
# Data collected for restaurant 157 in 33033.
# Data collected for restaurant 158 in 33033.
# Data collected for restaurant 159 in 33033.
# Data collected for restaurant 160 in 33033.
# Data collected for restaurant 161 in 33033.
# Data collected for restaurant 162 in 33033.
# Data collected for restaurant 163 in 33033.
# Data collected for restaurant 164 in 33033.
# Data collected for restaurant 165 in 33033.
# Data collected for restaurant 166 in 33033.
# Data collected for restaurant 167 in 33033.
# Data collected for restaurant 168 in 33033.
# Data collected for restaurant 169 in 33033.
# Data collected for restaurant 170 in 33033.
# Data collected for restaurant 171 in 33033.
# Data collected for restaurant 172 in 33033.
# 2496 total restaurants in 33033.
# zipcode 18 is 33033
# Searching 33168.
# ['Burger King', '12790 NW 7th Ave', 'North Miami', 'FL', '33168', 4.0, '$']
# Data collected for restaurant 173 in 33168.
# Data collected for restaurant 174 in 33168.
# Data collected for restaurant 175 in 33168.
# Data collected for restaurant 176 in 33168.
# Data collected for restaurant 177 in 33168.
# Data collected for restaurant 178 in 33168.
# Data collected for restaurant 179 in 33168.
# Data collected for restaurant 180 in 33168.
# Data collected for restaurant 181 in 33168.
# Data collected for restaurant 182 in 33168.
# Data collected for restaurant 183 in 33168.
# Data collected for restaurant 184 in 33168.
# Data collected for restaurant 185 in 33168.
# Data collected for restaurant 186 in 33168.
# Data collected for restaurant 187 in 33168.
# Data collected for restaurant 188 in 33168.
# Data collected for restaurant 189 in 33168.
# Data collected for restaurant 190 in 33168.
# Data collected for restaurant 191 in 33168.
# 2515 total restaurants in 33168.
# zipcode 19 is 33168
# Searching 33190.
# Key not found. Missing data.
# Data collected for restaurant 192 in 33190.
# Data collected for restaurant 193 in 33190.
# Data collected for restaurant 194 in 33190.
# Data collected for restaurant 195 in 33190.
# Data collected for restaurant 196 in 33190.
# Data collected for restaurant 197 in 33190.
# Data collected for restaurant 198 in 33190.
# Data collected for restaurant 199 in 33190.
# Data collected for restaurant 200 in 33190.
# Data collected for restaurant 201 in 33190.
# Data collected for restaurant 202 in 33190.
# Data collected for restaurant 203 in 33190.
# Data collected for restaurant 204 in 33190.
# Data collected for restaurant 205 in 33190.
# Data collected for restaurant 206 in 33190.
# Data collected for restaurant 207 in 33190.
# Data collected for restaurant 208 in 33190.
# Data collected for restaurant 209 in 33190.
# Data collected for restaurant 210 in 33190.
# Data collected for restaurant 211 in 33190.
# 2535 total restaurants in 33190.
# zipcode 20 is 33190
# Searching 33169.
# Key not found. Missing data.
# Data collected for restaurant 212 in 33169.
# Data collected for restaurant 213 in 33169.
# Data collected for restaurant 214 in 33169.
# Data collected for restaurant 215 in 33169.
# Data collected for restaurant 216 in 33169.
# Data collected for restaurant 217 in 33169.
# Data collected for restaurant 218 in 33169.
# Data collected for restaurant 219 in 33169.
# Data collected for restaurant 220 in 33169.
# Data collected for restaurant 221 in 33169.
# Data collected for restaurant 222 in 33169.
# Data collected for restaurant 223 in 33169.
# Data collected for restaurant 224 in 33169.
# Data collected for restaurant 225 in 33169.
# Data collected for restaurant 226 in 33169.
# Data collected for restaurant 227 in 33169.
# Data collected for restaurant 228 in 33169.
# Data collected for restaurant 229 in 33169.
# Data collected for restaurant 230 in 33169.
# Data collected for restaurant 231 in 33169.
# Data collected for restaurant 232 in 33169.
# 2556 total restaurants in 33169.
# zipcode 21 is 33169
# Searching 33181.
# ['Subres Grill', '2218 NE 123rd St', 'North Miami', 'FL', '33181', 4.5, '$$']
# Data collected for restaurant 233 in 33181.
# Data collected for restaurant 234 in 33181.
# Data collected for restaurant 235 in 33181.
# Data collected for restaurant 236 in 33181.
# Data collected for restaurant 237 in 33181.
# Data collected for restaurant 238 in 33181.
# Data collected for restaurant 239 in 33181.
# Data collected for restaurant 240 in 33181.
# Data collected for restaurant 241 in 33181.
# Data collected for restaurant 242 in 33181.
# Data collected for restaurant 243 in 33181.
# Data collected for restaurant 244 in 33181.
# Data collected for restaurant 245 in 33181.
# Data collected for restaurant 246 in 33181.
# Data collected for restaurant 247 in 33181.
# Data collected for restaurant 248 in 33181.
# Data collected for restaurant 249 in 33181.
# Data collected for restaurant 250 in 33181.
# Data collected for restaurant 251 in 33181.
# Data collected for restaurant 252 in 33181.
# Data collected for restaurant 253 in 33181.
# Data collected for restaurant 254 in 33181.
# 2578 total restaurants in 33181.
# zipcode 22 is 33181
# Searching 33030.
# Key not found. Missing data.
# Data collected for restaurant 255 in 33030.
# Data collected for restaurant 256 in 33030.
# Data collected for restaurant 257 in 33030.
# Data collected for restaurant 258 in 33030.
# Data collected for restaurant 259 in 33030.
# Data collected for restaurant 260 in 33030.
# Data collected for restaurant 261 in 33030.
# Data collected for restaurant 262 in 33030.
# Data collected for restaurant 263 in 33030.
# Data collected for restaurant 264 in 33030.
# Data collected for restaurant 265 in 33030.
# Data collected for restaurant 266 in 33030.
# Data collected for restaurant 267 in 33030.
# Data collected for restaurant 268 in 33030.
# Data collected for restaurant 269 in 33030.
# Data collected for restaurant 270 in 33030.
# Data collected for restaurant 271 in 33030.
# Data collected for restaurant 272 in 33030.
# Data collected for restaurant 273 in 33030.
# Data collected for restaurant 274 in 33030.
# Data collected for restaurant 275 in 33030.
# Data collected for restaurant 276 in 33030.
# Data collected for restaurant 277 in 33030.
# 2601 total restaurants in 33030.
# zipcode 23 is 33030
# Searching 33014.
# ['La Vina Aragon', '8155 W 8th Ave', 'Hialeah', 'FL', '33014', 4.5, '$']
# Data collected for restaurant 278 in 33014.
# Data collected for restaurant 279 in 33014.
# Data collected for restaurant 280 in 33014.
# Data collected for restaurant 281 in 33014.
# Data collected for restaurant 282 in 33014.
# Data collected for restaurant 283 in 33014.
# Data collected for restaurant 284 in 33014.
# Data collected for restaurant 285 in 33014.
# Data collected for restaurant 286 in 33014.
# Data collected for restaurant 287 in 33014.
# Data collected for restaurant 288 in 33014.
# Data collected for restaurant 289 in 33014.
# Data collected for restaurant 290 in 33014.
# Data collected for restaurant 291 in 33014.
# Data collected for restaurant 292 in 33014.
# Data collected for restaurant 293 in 33014.
# Data collected for restaurant 294 in 33014.
# Data collected for restaurant 295 in 33014.
# Data collected for restaurant 296 in 33014.
# Data collected for restaurant 297 in 33014.
# Data collected for restaurant 298 in 33014.
# Data collected for restaurant 299 in 33014.
# Data collected for restaurant 300 in 33014.
# Data collected for restaurant 301 in 33014.
# 2625 total restaurants in 33014.
# zipcode 24 is 33014
# Searching 33193.
# Key not found. Missing data.
# Data collected for restaurant 302 in 33193.
# Data collected for restaurant 303 in 33193.
# Data collected for restaurant 304 in 33193.
# Data collected for restaurant 305 in 33193.
# Data collected for restaurant 306 in 33193.
# Data collected for restaurant 307 in 33193.
# Data collected for restaurant 308 in 33193.
# Data collected for restaurant 309 in 33193.
# Data collected for restaurant 310 in 33193.
# Data collected for restaurant 311 in 33193.
# Data collected for restaurant 312 in 33193.
# Data collected for restaurant 313 in 33193.
# Data collected for restaurant 314 in 33193.
# Data collected for restaurant 315 in 33193.
# Data collected for restaurant 316 in 33193.
# Data collected for restaurant 317 in 33193.
# Data collected for restaurant 318 in 33193.
# Data collected for restaurant 319 in 33193.
# Data collected for restaurant 320 in 33193.
# Data collected for restaurant 321 in 33193.
# Data collected for restaurant 322 in 33193.
# Data collected for restaurant 323 in 33193.
# Data collected for restaurant 324 in 33193.
# Data collected for restaurant 325 in 33193.
# Data collected for restaurant 326 in 33193.
# 2650 total restaurants in 33193.
# zipcode 25 is 33193
# Searching 33016.
# Key not found. Missing data.
# Data collected for restaurant 327 in 33016.
# Data collected for restaurant 328 in 33016.
# Data collected for restaurant 329 in 33016.
# Data collected for restaurant 330 in 33016.
# Data collected for restaurant 331 in 33016.
# Data collected for restaurant 332 in 33016.
# Data collected for restaurant 333 in 33016.
# Data collected for restaurant 334 in 33016.
# Data collected for restaurant 335 in 33016.
# Data collected for restaurant 336 in 33016.
# Data collected for restaurant 337 in 33016.
# Data collected for restaurant 338 in 33016.
# Data collected for restaurant 339 in 33016.
# Data collected for restaurant 340 in 33016.
# Data collected for restaurant 341 in 33016.
# Data collected for restaurant 342 in 33016.
# Data collected for restaurant 343 in 33016.
# Data collected for restaurant 344 in 33016.
# Data collected for restaurant 345 in 33016.
# Data collected for restaurant 346 in 33016.
# Data collected for restaurant 347 in 33016.
# Data collected for restaurant 348 in 33016.
# Data collected for restaurant 349 in 33016.
# Data collected for restaurant 350 in 33016.
# Data collected for restaurant 351 in 33016.
# Data collected for restaurant 352 in 33016.
# 2676 total restaurants in 33016.
# zipcode 26 is 33016
# Searching 33161.
# Key not found. Missing data.
# Data collected for restaurant 353 in 33161.
# Data collected for restaurant 354 in 33161.
# Data collected for restaurant 355 in 33161.
# Data collected for restaurant 356 in 33161.
# Data collected for restaurant 357 in 33161.
# Data collected for restaurant 358 in 33161.
# Data collected for restaurant 359 in 33161.
# Data collected for restaurant 360 in 33161.
# Data collected for restaurant 361 in 33161.
# Data collected for restaurant 362 in 33161.
# Data collected for restaurant 363 in 33161.
# Data collected for restaurant 364 in 33161.
# Data collected for restaurant 365 in 33161.
# Data collected for restaurant 366 in 33161.
# Data collected for restaurant 367 in 33161.
# Data collected for restaurant 368 in 33161.
# Data collected for restaurant 369 in 33161.
# Data collected for restaurant 370 in 33161.
# Data collected for restaurant 371 in 33161.
# Data collected for restaurant 372 in 33161.
# Data collected for restaurant 373 in 33161.
# Data collected for restaurant 374 in 33161.
# Data collected for restaurant 375 in 33161.
# Data collected for restaurant 376 in 33161.
# Data collected for restaurant 377 in 33161.
# Data collected for restaurant 378 in 33161.
# Data collected for restaurant 379 in 33161.
# 2703 total restaurants in 33161.
# zipcode 27 is 33161
# Searching 33184.
# ['Sancho Restaurant', '13202 SW 8th St', 'Miami', 'FL', '33184', 3.5, '$$$']
# Data collected for restaurant 380 in 33184.
# Data collected for restaurant 381 in 33184.
# Data collected for restaurant 382 in 33184.
# Data collected for restaurant 383 in 33184.
# Data collected for restaurant 384 in 33184.
# Data collected for restaurant 385 in 33184.
# Data collected for restaurant 386 in 33184.
# Data collected for restaurant 387 in 33184.
# Data collected for restaurant 388 in 33184.
# Data collected for restaurant 389 in 33184.
# Data collected for restaurant 390 in 33184.
# Data collected for restaurant 391 in 33184.
# Data collected for restaurant 392 in 33184.
# Data collected for restaurant 393 in 33184.
# Data collected for restaurant 394 in 33184.
# Data collected for restaurant 395 in 33184.
# Data collected for restaurant 396 in 33184.
# Data collected for restaurant 397 in 33184.
# Data collected for restaurant 398 in 33184.
# Data collected for restaurant 399 in 33184.
# Data collected for restaurant 400 in 33184.
# Data collected for restaurant 401 in 33184.
# Data collected for restaurant 402 in 33184.
# Data collected for restaurant 403 in 33184.
# Data collected for restaurant 404 in 33184.
# Data collected for restaurant 405 in 33184.
# Data collected for restaurant 406 in 33184.
# Data collected for restaurant 407 in 33184.
# 2731 total restaurants in 33184.
# zipcode 28 is 33184
# Searching 33194.
# Key not found. Missing data.
# Data collected for restaurant 408 in 33194.
# Data collected for restaurant 409 in 33194.
# Data collected for restaurant 410 in 33194.
# Data collected for restaurant 411 in 33194.
# Data collected for restaurant 412 in 33194.
# Data collected for restaurant 413 in 33194.
# Data collected for restaurant 414 in 33194.
# Data collected for restaurant 415 in 33194.
# Data collected for restaurant 416 in 33194.
# Data collected for restaurant 417 in 33194.
# Data collected for restaurant 418 in 33194.
# Data collected for restaurant 419 in 33194.
# Data collected for restaurant 420 in 33194.
# Data collected for restaurant 421 in 33194.
# Data collected for restaurant 422 in 33194.
# Data collected for restaurant 423 in 33194.
# Data collected for restaurant 424 in 33194.
# Data collected for restaurant 425 in 33194.
# Data collected for restaurant 426 in 33194.
# Data collected for restaurant 427 in 33194.
# Data collected for restaurant 428 in 33194.
# Data collected for restaurant 429 in 33194.
# Data collected for restaurant 430 in 33194.
# Data collected for restaurant 431 in 33194.
# Data collected for restaurant 432 in 33194.
# Data collected for restaurant 433 in 33194.
# Data collected for restaurant 434 in 33194.
# Data collected for restaurant 435 in 33194.
# Data collected for restaurant 436 in 33194.
# 2760 total restaurants in 33194.
# zipcode 29 is 33194
# Searching 33035.
# Key not found. Missing data.
# Data collected for restaurant 437 in 33035.
# Data collected for restaurant 438 in 33035.
# Data collected for restaurant 439 in 33035.
# Data collected for restaurant 440 in 33035.
# Data collected for restaurant 441 in 33035.
# Data collected for restaurant 442 in 33035.
# Data collected for restaurant 443 in 33035.
# Data collected for restaurant 444 in 33035.
# Data collected for restaurant 445 in 33035.
# Data collected for restaurant 446 in 33035.
# Data collected for restaurant 447 in 33035.
# Data collected for restaurant 448 in 33035.
# Data collected for restaurant 449 in 33035.
# Data collected for restaurant 450 in 33035.
# Data collected for restaurant 451 in 33035.
# Data collected for restaurant 452 in 33035.
# Data collected for restaurant 453 in 33035.
# Data collected for restaurant 454 in 33035.
# Data collected for restaurant 455 in 33035.
# Data collected for restaurant 456 in 33035.
# Data collected for restaurant 457 in 33035.
# Data collected for restaurant 458 in 33035.
# Data collected for restaurant 459 in 33035.
# Data collected for restaurant 460 in 33035.
# Data collected for restaurant 461 in 33035.
# Data collected for restaurant 462 in 33035.
# Data collected for restaurant 463 in 33035.
# Data collected for restaurant 464 in 33035.
# Data collected for restaurant 465 in 33035.
# Data collected for restaurant 466 in 33035.
# 2790 total restaurants in 33035.
# zipcode 30 is 33035
# -----------------------------------
# Data Retrieval Complete

# %%
# Loop through the zipcodes in zip_list and append restaurant info to lists above
print("Beginning Data Retrieval")
print("-----------------------------------")

restaurants = []

for zipc in zip_list:
    loc = zipc
    try:
        output = get_restaurants(loc)
        print(output)
        restaurants.append(output)

        For x in restaurants:
        names.append(output[0])
        streets.append(output[1])
        cities.append(output[2])
        states.append(output[3])
        zipcodes.append(output[4])
        ratings.append(output[5])
        price.append(output[6])
        
# make exception for key errors        
    except (KeyError, IndexError):
        print(f'Key missing')
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
        names.append(output[0])
        addresses.append(output[1])
        zipcode.append(zipc)
        lats.append(output[2])
        lons.append(output[3])
        ratings.append(output[4])
        price.append(output[5])

print("-----------------------------------")
print("Data Retrieval Complete")

    
print("done!")

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
restaurants_df = pd.DataFrame({"Name": names,"Location": addresses,"Zipcode":zipcode, "Rating": ratings,"Price": price})

# %%
restaurants_df.sort_values(by=["Zipcode"], ascending=True)

print(f"The data frame contains {len(restaurants_df['Name'])} unique restaurants.")

restaurants_df

# %%
# Save Data to csv
#cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
#cities_pd.head(10)
