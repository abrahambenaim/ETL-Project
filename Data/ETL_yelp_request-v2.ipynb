# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Yelp API Key
gkey = 'fxuoEjmZHd5kA1x20u4z2waSsXfTm49pWr2F6ac-htERJ0haCqXH949tlmDYt9lhy4MC6nBJjt2llMwhQJfxbwX69QlFkI221WkMDZTn7NMQBaXRrWGBFzCrg4-9XXYx'

# %%
from etl_clean_ip import zip_list
# Out:
# /Users/monicamalarcon/Dropbox/School/UM_Bootcamp/Work_Bootcamp/13 - ETL-Project/ETL-project/ETL-Project/Data/etl_clean_ip.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   top30_disparity['zip_code'] = top30_disparity['zip_code'].astype(int)
# /Users/monicamalarcon/Dropbox/School/UM_Bootcamp/Work_Bootcamp/13 - ETL-Project/ETL-project/ETL-Project/Data/etl_clean_ip.py:232: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   top30_disparity['Avg_income'] = top30_disparity['Avg_income'].round(3)

# %%
#set up base url
# base url
base_url = "https://api.yelp.com/v3/businesses/search"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(target_loc,target_key,target_type):
    params = {
    "location": target_loc,
    "term": target_key,
    "categories": target_type,
}
    return params

# run a request using our params dictionary
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
# Import zip list
zip_list 


#cities_pd.shape[0] #use .shape[0] to count the number of rows
# Out:
# [33142,
#  33127,
#  33147,
#  33125,
#  33136,
#  33012,
#  33167,
#  33126,
#  33150,
#  33032,
#  33130,
#  33162,
#  33034,
#  33055,
#  33056,
#  33174,
#  33172,
#  33033,
#  33168,
#  33190,
#  33169,
#  33181,
#  33030,
#  33014,
#  33193,
#  33016,
#  33161,
#  33184,
#  33194,
#  33035]

# %%
# create empty lists to hold yelp data
names = []
addresses = []
lats = []
lons = []
ratings = []
price = []

#define Yelp function to get restaurant data
def get_restaurants(loc):
    
    #these are the additional params
    add_params = { "limit" : 10, "radius" : 40000}

    #these are the original params
    params = s_params(loc,"restaurants","restaurants, All")

    #add additional params to our params from before
    s1_params = {**params,**add_params}

    s1_results = s_query(base_url,headers,s1_params)
    
    if (s1_results):
    
        name = s1_results["businesses"][0]["name"]
        address = s1_results["businesses"][0]["location"]["display_address"]
        lat = s1_results["businesses"][0]["coordinates"]["latitude"]
        lon = s1_results["businesses"][0]["coordinates"]["longitude"]
        rating = s1_results["businesses"][0]["rating"]
        price = s1_results["businesses"][0]["price"]
        output = [name,address,lat,lon,rating,price] 
    else:
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
    
    
    return output

# %%
# Loop through the zipcodes in zip_list and append restaurant info to lists above

print("wait...")
print("Beginning Data Retrieval")
print("-----------------------------------")

for zipc in zip_list:
    loc = zipc
    try:
        output = get_restaurants(loc)
        print(output)
        names.append(output[0])
        addresses.append(output[1])
        lats.append(output[2])
        lons.append(output[3])
        ratings.append(output[4])
        price.append(output[5])
        
# make exception for key errors        
    except (KeyError, IndexError):
        print(f'Key missing')
        output = ["NaN","NaN","NaN","NaN","NaN","NaN"]
        names.append(output[0])
        addresses.append(output[1])
        lats.append(output[2])
        lons.append(output[3])
        ratings.append(output[4])
        price.append(output[5])

print("-----------------------------------")
print("Data Retrieval Complete")

    
print("done!")
# Out:
# wait...
# Beginning Data Retrieval
# -----------------------------------
# ['Hometown Bar-B-Que', ['1200 NW 22nd St', 'Ste 100', 'Miami, FL 33142'], 25.797445333, -80.215986833, 4.5, '$$']
# ['KYU', ['251 NW 25th St', 'Miami, FL 33127'], 25.80089, -80.20017, 4.5, '$$$']
# ['Sins Gastrobar', ['9835 NE 2nd Ave', 'Miami Shores, FL 33138'], 25.86562, -80.19331, 4.0, '$$']
# ["Old's Havana Cuban Bar & Cocina", ['1442 SW 8th St', 'Miami, FL 33135'], 25.7655942148975, -80.2192383373502, 4.5, '$$']
# ["Old's Havana Cuban Bar & Cocina", ['1442 SW 8th St', 'Miami, FL 33135'], 25.7655942148975, -80.2192383373502, 4.5, '$$']
# Key missing
# ['Sins Gastrobar', ['9835 NE 2nd Ave', 'Miami Shores, FL 33138'], 25.86562, -80.19331, 4.0, '$$']
# ['Amor di Pasta - Blue Lagoon', ['536 NW 57th Ave', 'Miami, FL 33126'], 25.776908, -80.288655, 4.5, '$$']
# ['Sins Gastrobar', ['9835 NE 2nd Ave', 'Miami Shores, FL 33138'], 25.86562, -80.19331, 4.0, '$$']
# Key missing
# ["Old's Havana Cuban Bar & Cocina", ['1442 SW 8th St', 'Miami, FL 33135'], 25.7655942148975, -80.2192383373502, 4.5, '$$']
# ['Korean Kitchen', ['1661 NE 163rd St', 'Ste A', 'North Miami Beach, FL 33162'], 25.92621, -80.16672, 4.5, '$$']
# ['Blackwater Siren', ['107690 Overseas Hwy', 'Key Largo, FL 33037'], 25.1831299, -80.38696, 4.5, '$$']
# ['Hi Pot Pembroke Pines', ['620 N University Dr', 'Pembroke Pines, FL 33024'], 26.014611, -80.251263, 4.5, '$$']
# ['World Famous', ['19401 NW 27th Ave', 'Miami Gardens, FL 33056'], 25.95109, -80.2450747042894, 4.0, '$$']
# ['KOW Restaurant', ['14429 SW 42nd St', 'Miami, FL 33175'], 25.729489, -80.428437, 4.5, '$$']
# ['Bocas House- Doral', ['10200 NW 25th St', 'Ste 101', 'Doral, FL 33172'], 25.7963099, -80.3619, 4.0, '$$']
# ['Yardie Spice', ['225 S Krome Ave', 'Homestead, FL 33030'], 25.468072, -80.477266, 5.0, '$$']
# ['World Famous House of Mac', ['13521 Biscayne Blvd', 'North Miami Beach, FL 33181'], 25.90059, -80.15972, 4.5, '$$']
# ['Black Point Ocean Grill', ['24775 SW 87th Ave', 'Cutler Bay, FL 33032'], 25.540609, -80.328529, 4.0, '$$']
# ['World Famous House of Mac', ['13521 Biscayne Blvd', 'North Miami Beach, FL 33181'], 25.90059, -80.15972, 4.5, '$$']
# ['World Famous House of Mac', ['13521 Biscayne Blvd', 'North Miami Beach, FL 33181'], 25.90059, -80.15972, 4.5, '$$']
# ['Yardie Spice', ['225 S Krome Ave', 'Homestead, FL 33030'], 25.468072, -80.477266, 5.0, '$$']
# ['107 Taste - Miami Lakes', ['6705 Main St', 'Miami Lakes, FL 33014'], 25.9133462, -80.3097048, 4.5, '$$']
# ['KOW Restaurant', ['14429 SW 42nd St', 'Miami, FL 33175'], 25.729489, -80.428437, 4.5, '$$']
# Key missing
# ['World Famous House of Mac', ['13521 Biscayne Blvd', 'North Miami Beach, FL 33181'], 25.90059, -80.15972, 4.5, '$$']
# ['KOW Restaurant', ['14429 SW 42nd St', 'Miami, FL 33175'], 25.729489, -80.428437, 4.5, '$$']
# ['KOW Restaurant', ['14429 SW 42nd St', 'Miami, FL 33175'], 25.729489, -80.428437, 4.5, '$$']
# ['Yardie Spice', ['225 S Krome Ave', 'Homestead, FL 33030'], 25.468072, -80.477266, 5.0, '$$']
# -----------------------------------
# Data Retrieval Complete
# done!

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
restaurants_df = pd.DataFrame({"Name": names,"Location": addresses,"Rating": ratings,"Price": price})
restaurants_df.dropna(how="any")
restaurants_df
# Out:
#                                Name  \
# 0                Hometown Bar-B-Que
# 1                               KYU
# 2                    Sins Gastrobar
# 3   Old's Havana Cuban Bar & Cocina
# 4   Old's Havana Cuban Bar & Cocina
# 5                               NaN
# 6                    Sins Gastrobar
# 7       Amor di Pasta - Blue Lagoon
# 8                    Sins Gastrobar
# 9                               NaN
# 10  Old's Havana Cuban Bar & Cocina
# 11                   Korean Kitchen
# 12                 Blackwater Siren
# 13            Hi Pot Pembroke Pines
# 14                     World Famous
# 15                   KOW Restaurant
# 16               Bocas House- Doral
# 17                     Yardie Spice
# 18        World Famous House of Mac
# 19          Black Point Ocean Grill
# 20        World Famous House of Mac
# 21        World Famous House of Mac
# 22                     Yardie Spice
# 23          107 Taste - Miami Lakes
# 24                   KOW Restaurant
# 25                              NaN
# 26        World Famous House of Mac
# 27                   KOW Restaurant
# 28                   KOW Restaurant
# 29                     Yardie Spice
# 30               Hometown Bar-B-Que
# 31                              KYU
# 32                   Sins Gastrobar
# 33  Old's Havana Cuban Bar & Cocina
# 34  Old's Havana Cuban Bar & Cocina
# 35                              NaN
# 36                   Sins Gastrobar
# 37      Amor di Pasta - Blue Lagoon
# 38                   Sins Gastrobar
# 39                              NaN
# 40  Old's Havana Cuban Bar & Cocina
# 41                   Korean Kitchen
# 42                 Blackwater Siren
# 43            Hi Pot Pembroke Pines
# 44                     World Famous
# 45                   KOW Restaurant
# 46               Bocas House- Doral
# 47                     Yardie Spice
# 48        World Famous House of Mac
# 49          Black Point Ocean Grill
# 50        World Famous House of Mac
# 51        World Famous House of Mac
# 52                     Yardie Spice
# 53          107 Taste - Miami Lakes
# 54                   KOW Restaurant
# 55                              NaN
# 56        World Famous House of Mac
# 57                   KOW Restaurant
# 58                   KOW Restaurant
# 59                     Yardie Spice
#
#                                              Location Rating Price
# 0         [1200 NW 22nd St, Ste 100, Miami, FL 33142]    4.5    $$
# 1                   [251 NW 25th St, Miami, FL 33127]    4.5   $$$
# 2           [9835 NE 2nd Ave, Miami Shores, FL 33138]      4    $$
# 3                   [1442 SW 8th St, Miami, FL 33135]    4.5    $$
# 4                   [1442 SW 8th St, Miami, FL 33135]    4.5    $$
# 5                                                 NaN    NaN   NaN
# 6           [9835 NE 2nd Ave, Miami Shores, FL 33138]      4    $$
# 7                  [536 NW 57th Ave, Miami, FL 33126]    4.5    $$
# 8           [9835 NE 2nd Ave, Miami Shores, FL 33138]      4    $$
# 9                                                 NaN    NaN   NaN
# 10                  [1442 SW 8th St, Miami, FL 33135]    4.5    $$
# 11  [1661 NE 163rd St, Ste A, North Miami Beach, F...    4.5    $$
# 12         [107690 Overseas Hwy, Key Largo, FL 33037]    4.5    $$
# 13    [620 N University Dr, Pembroke Pines, FL 33024]    4.5    $$
# 14       [19401 NW 27th Ave, Miami Gardens, FL 33056]      4    $$
# 15                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 16       [10200 NW 25th St, Ste 101, Doral, FL 33172]      4    $$
# 17             [225 S Krome Ave, Homestead, FL 33030]      5    $$
# 18  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 19          [24775 SW 87th Ave, Cutler Bay, FL 33032]      4    $$
# 20  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 21  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 22             [225 S Krome Ave, Homestead, FL 33030]      5    $$
# 23              [6705 Main St, Miami Lakes, FL 33014]    4.5    $$
# 24                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 25                                                NaN    NaN   NaN
# 26  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 27                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 28                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 29             [225 S Krome Ave, Homestead, FL 33030]      5    $$
# 30        [1200 NW 22nd St, Ste 100, Miami, FL 33142]    4.5    $$
# 31                  [251 NW 25th St, Miami, FL 33127]    4.5   $$$
# 32          [9835 NE 2nd Ave, Miami Shores, FL 33138]      4    $$
# 33                  [1442 SW 8th St, Miami, FL 33135]    4.5    $$
# 34                  [1442 SW 8th St, Miami, FL 33135]    4.5    $$
# 35                                                NaN    NaN   NaN
# 36          [9835 NE 2nd Ave, Miami Shores, FL 33138]      4    $$
# 37                 [536 NW 57th Ave, Miami, FL 33126]    4.5    $$
# 38          [9835 NE 2nd Ave, Miami Shores, FL 33138]      4    $$
# 39                                                NaN    NaN   NaN
# 40                  [1442 SW 8th St, Miami, FL 33135]    4.5    $$
# 41  [1661 NE 163rd St, Ste A, North Miami Beach, F...    4.5    $$
# 42         [107690 Overseas Hwy, Key Largo, FL 33037]    4.5    $$
# 43    [620 N University Dr, Pembroke Pines, FL 33024]    4.5    $$
# 44       [19401 NW 27th Ave, Miami Gardens, FL 33056]      4    $$
# 45                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 46       [10200 NW 25th St, Ste 101, Doral, FL 33172]      4    $$
# 47             [225 S Krome Ave, Homestead, FL 33030]      5    $$
# 48  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 49          [24775 SW 87th Ave, Cutler Bay, FL 33032]      4    $$
# 50  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 51  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 52             [225 S Krome Ave, Homestead, FL 33030]      5    $$
# 53              [6705 Main St, Miami Lakes, FL 33014]    4.5    $$
# 54                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 55                                                NaN    NaN   NaN
# 56  [13521 Biscayne Blvd, North Miami Beach, FL 33...    4.5    $$
# 57                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 58                [14429 SW 42nd St, Miami, FL 33175]    4.5    $$
# 59             [225 S Krome Ave, Homestead, FL 33030]      5    $$

# %%
print(f"The data frame contains {len(restaurants_df['Name'])} unique restaurants.")

      
restaurants_df

# %%
# Save Data to csv
#cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
#cities_pd.head(10)
